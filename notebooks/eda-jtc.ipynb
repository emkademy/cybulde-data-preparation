# %%
cd /app
# Out:
# /app

# %%
import pandas as pd

# %%
train_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/train.csv")
test_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test.csv")
test_labels_df = pd.read_csv("./data/raw/jigsaw-toxic-comments/test_labels.csv")

# %%
print(f"{train_df.shape=}")
print(f"{test_df.shape=}")
print(f"{test_labels_df.shape=}")
# Out:
# train_df.shape=(159571, 8)
# test_df.shape=(153164, 2)
# test_labels_df.shape=(153164, 7)

# %%
len(train_df) * 0.06
# Out:
# 9574.26

# %%
train_df.sample(n=50)
# Out:
#                       id                                       comment_text  \
# 91522   f4b7100856e95258  Thanks ElKevbo, sorry I didn't know that. 96.2...
# 88179   ebe21965f1d42875  "\n\n Wikipedian in Residence \n\nI'm working ...
# 99484   143257c19c445b87  "\n\nI don't think you're a good admin if you'...
# 31481   539a5bcd3db8fffb  Not until we resolve this issue, you apologise...
# 112478  59ab35308f649306  "\n\n Amir Abbas Fakhravar \n\nSiavash's comme...
# 116916  70f97021c6d4be1a  BTW: reverting things back without first havin...
# 66429   b1b91fbcf425a0e0              But everything was factually correct!
# 98848   10c955efb354b4aa  "\n\nPlease stop removing content from Wikiped...
# 152324  8b93088cf0addb77  "\n\nAs additional information, I have provide...
# 148289  49b7ba13d9d646dd  ]]\n\n Blue Bus of Bolton \nHi there - just so...
# 152436  8d5f9e9dd1cbbc53  "\n\n THANKS FOR THE USELESS ATTEMPT \n\nI app...
# 104912  3141d3fe47c2453e  Go ahead and shorten the footnotes as long as ...
# 131923  c1e9ded97972e2b9  Semi-protected edit request on 16 February 201...
# 68197   b66e3d2a51aa2854  My rationale for assessment: Ukraine is one of...
# 71310   bedda11728f726b0  "\n\nPage move\n\nWhy has this page been moved...
# 113667  5fd437a7661ef88f  "\n\n Developer access \n\nI actually agree th...
# 6054    10287ae7c4dc4ebe  "\n\nMy god how childish are you! You mean the...
# 39450   6945fa3e6b06d40a  "\n\nPlease refrain from assuming things that ...
# 122473  8f26ac67c852de9e  "\n\nHere are a few key questions:\n Do you un...
# 151397  7c5e415e0c6dbb86  Sign your comments. His name has been publishe...
# 108552  445b71f7a6592276  "==Regarding edits made during December 19 200...
# 93847   faf0008f533c9465  "\n\n regarding a wiki writer \n\nRegarding th...
# 100624  1a8f554bef7e1ac6  "\n Simply being listed on a record label's we...
# 41223   6dfa66fef2e9516d  Engineer \nYou hope you don't design buildings...
# 87338   e9af5eba6b8459e5  "It's a predicate adjective, Wikipedio...ans. ...
# 43085   72f2456420da62a0  Calm down chaps. But perhaps you should try to...
# 54315   912179a27d65fedf  "\n Fixing Assange and resistance: I have pref...
# 83004   de11b0b0562fefc4  Re:75.67.216.103\n\nHeh. You think you're goin...
# 128231  adbf3215c661be60  That being said, Ludvikus should ask Batvette ...
# 20133   352dc04f9d307952  Balls: courage\nthis could definitely be a wik...
# 129367  b3ecaabe8309806d                            Todd, you're a dumbass.
# 26290   4596fe628abccef6  "\nWhen these two have used their combined RR'...
# 158240  eadccfa32dedbe6b  Please Demiurge, think about what you are sayi...
# 23334   3d9c2a25d3e8f759  Thanks for popping in with the info requested ...
# 83099   de51e46b53ece8bb  I am impressed that so many editors have noted...
# 112415  596151b74a2d4c14  Wikipedia:Articles for deletion/Condorcet Inst...
# 151809  83268fe65875a254  The  Bavarian Geographer describes a multitude...
# 31986   54fc31b0b210f4e2  "\nSwapping images, so leaving the Helton imag...
# 107597  3f356f9690282a39  "\n\n{| style=""border-spacing:8px;margin:0px ...
# 129606  b54ced1a50ba0e19  "\n\nBaroque Guitars are NOT ""ten-string guit...
# 63861   aaddc9d9dcd80569  "\n\nSorry for being so WP:BOLD, and thanks fo...
# 98714   100f5a24cc51e763  I added perfectly good critisism about ichigo....
# 128905  b161a3fd0beba349  "\n\n""Jon513 has provided several highly auth...
# 7905    150a83d7bb1679f0  I said no such thing.  Please don't put words ...
# 17753   2edeaa3725e35abc  India has 1.1 bn people, one-sixth of all huma...
# 73729   c54be1a0ed26fc71  FUCK YOU DUMBASS ITS AN OPINION AND DONT DELET...
# 4729    0c88d2cc44cbec1f  How dare you accuse others of vandalism when y...
# 21941   39cfe517e236dc5a  Oh, and the guy who runs NexGenwars is 18 year...
# 130527  ba4999c5e356f049  "\n\n New Messages \n\n ←Signed:→Mr. E. Sánche...
# 155556  bff59f526e2fe3ee  I have requested permission to use some photog...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 91522       0             0        0       0       0              0
# 88179       0             0        0       0       0              0
# 99484       0             0        0       0       0              0
# 31481       0             0        0       0       0              0
# 112478      0             0        0       0       0              0
# 116916      0             0        0       0       0              0
# 66429       0             0        0       0       0              0
# 98848       0             0        0       0       0              0
# 152324      1             0        1       0       0              0
# 148289      0             0        0       0       0              0
# 152436      0             0        0       0       0              0
# 104912      0             0        0       0       0              0
# 131923      0             0        0       0       0              0
# 68197       0             0        0       0       0              0
# 71310       0             0        0       0       0              0
# 113667      0             0        0       0       0              0
# 6054        0             0        0       0       0              0
# 39450       0             0        0       0       0              0
# 122473      0             0        0       0       0              0
# 151397      0             0        0       0       0              0
# 108552      0             0        0       0       0              0
# 93847       0             0        0       0       0              0
# 100624      0             0        0       0       0              0
# 41223       1             0        0       0       1              0
# 87338       0             0        0       0       0              0
# 43085       0             0        0       0       0              0
# 54315       0             0        0       0       0              0
# 83004       1             0        0       0       0              0
# 128231      0             0        0       0       0              0
# 20133       0             0        0       0       0              0
# 129367      1             0        1       0       1              0
# 26290       0             0        0       0       0              0
# 158240      0             0        0       0       0              0
# 23334       0             0        0       0       0              0
# 83099       0             0        0       0       0              0
# 112415      0             0        0       0       0              0
# 151809      0             0        0       0       0              0
# 31986       0             0        0       0       0              0
# 107597      0             0        0       0       0              0
# 129606      0             0        0       0       0              0
# 63861       0             0        0       0       0              0
# 98714       0             0        0       0       0              0
# 128905      0             0        0       0       0              0
# 7905        0             0        0       0       0              0
# 17753       0             0        0       0       0              0
# 73729       1             1        1       0       1              0
# 4729        0             0        0       0       0              0
# 21941       0             0        0       0       0              0
# 130527      0             0        0       0       0              0
# 155556      0             0        0       0       0              0

# %%
train_df["identity_hate"].unique()
# Out:
# array([0, 1])

# %%
test_df.head(50)
# Out:
#                   id                                       comment_text
# 0   00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1   0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2   00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3   00017563c3f7919a  :If you have a look back at the source, the in...
# 4   00017695ad8997eb          I don't anonymously edit articles at all.
# 5   0001ea8717f6de06  Thank you for understanding. I think very high...
# 6   00024115d4cbde0f  Please do not add nonsense to Wikipedia. Such ...
# 7   000247e83dcc1211                   :Dear god this site is horrible.
# 8   00025358d4737918  " \n Only a fool can believe in such numbers. ...
# 9   00026d1092fe71cc  == Double Redirects == \n\n When fixing double...
# 10  0002eadc3b301559  I think its crap that the link to roggenbier i...
# 11  0002f87b16116a7f  "::: Somebody will invariably try to add Relig...
# 12  0003806b11932181  , 25 February 2010 (UTC) \n\n :::Looking it ov...
# 13  0003e1cccfd5a40a  " \n\n It says it right there that it IS a typ...
# 14  00059ace3e3e9a53  " \n\n == Before adding a new product to the l...
# 15  000634272d0d44eb  ==Current Position== \n Anyone have confirmati...
# 16  000663aff0fffc80                           this other one from 1897
# 17  000689dd34e20979  == Reason for banning throwing == \n\n This ar...
# 18  000834769115370c  :: Wallamoose was changing the cited material ...
# 19  000844b52dee5f3f             |blocked]] from editing Wikipedia.   |
# 20  00084da5d4ead7aa  ==Indefinitely blocked== \n I have indefinitel...
# 21  00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 22  000968ce11f5ee34  Please stop. If you continue to vandalize Wiki...
# 23  0009734200a85047  == Energy  == \n\n I have edited the introduct...
# 24  00097b6214686db5  :yeah, thanks for reviving the tradition of pi...
# 25  0009aef4bd9e1697  MLM Software,NBFC software,Non Banking Financi...
# 26  000a02d807ae0254  @RedSlash, cut it short. If you have sources s...
# 27  000a6c6d4e89b9bc  ==================== \n Deception is the way o...
# 28  000bafe2080bba82  . \n\n           Jews are not a race because y...
# 29  000bf0a9894b2807  :::If Ollie or others think that one list of t...
# 30  000c50dceb1eed2b  " \n *Support Per Jimbo and WP:google ""Climat...
# 31  000c9b92318552d1               Professors to the Manhatten Project.
# 32  000ce41d86f2b886  :::::I have added more wikilinks to my section...
# 33  000cf60dbaed8c02  " \n\n :Not sure whether this is notable enoug...
# 34  000d4f120d5a7303                       일이삼사오육칠팔구하고십이요 에헤헤 으헤 으헤 으허허
# 35  000d60becb7d1a67  I've deleted the page , as we have no evidence...
# 36  000fc381d4895598  == Nation Radio - request for comment == \n\n ...
# 37  000ff37cf57ab537                          """ (per your user page)"
# 38  001068b809feee6b  " \n\n ==balance== \n This page has one senten...
# 39  0011c58fcfd6bf91  " \n\n *@EdJohnston. Your question was about f...
# 40  0011cefc680993ba                      REDIRECT Talk:Mi Vida Eres Tú
# 41  0011ef6aa33d42e6  " \n I'm not convinced that he was blind. Wher...
# 42  0012706ac77a7b37  == Thanks for the Barnstar! == \n\n Thank you ...
# 43  0012bb72f20ae971  " \n\n == Ref: SS Ponzi Scheme == \n\n Hi Padi...
# 44  0012bbcbd6958302  " \n\n Look, Gerry Spence has NOT ""never lost...
# 45  00137446b1aec28c  == September 20th Truce == \n\n According to s...
# 46  0013a435effa29bd  I'd never think I'd need to say it, but Wikipe...
# 47  0013be435187e84f  But this is not the article about government p...
# 48  0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 49  001411adf8f1dd82  == Dracula's Grandmother == \n\n  \n Dracula's...

# %%
test_labels_df.head(10)
# Out:
#                  id  toxic  severe_toxic  obscene  threat  insult  \
# 0  00001cee341fdb12     -1            -1       -1      -1      -1
# 1  0000247867823ef7     -1            -1       -1      -1      -1
# 2  00013b17ad220c46     -1            -1       -1      -1      -1
# 3  00017563c3f7919a     -1            -1       -1      -1      -1
# 4  00017695ad8997eb     -1            -1       -1      -1      -1
# 5  0001ea8717f6de06      0             0        0       0       0
# 6  00024115d4cbde0f     -1            -1       -1      -1      -1
# 7  000247e83dcc1211      0             0        0       0       0
# 8  00025358d4737918     -1            -1       -1      -1      -1
# 9  00026d1092fe71cc     -1            -1       -1      -1      -1
#
#    identity_hate
# 0             -1
# 1             -1
# 2             -1
# 3             -1
# 4             -1
# 5              0
# 6             -1
# 7              0
# 8             -1
# 9             -1

# %%
test_labels_df["toxic"].unique()
# Out:
# array([-1,  0,  1])

# %%
test_labels_df[test_labels_df["toxic"] != -1].shape
# Out:
# (63978, 7)

# %%
test_labels_df[
    (test_labels_df["toxic"] != -1) &
    (test_labels_df["severe_toxic"] != -1) &
    (test_labels_df["obscene"] != -1) &
    (test_labels_df["threat"] != -1) &
    (test_labels_df["insult"] != -1) &
    (test_labels_df["identity_hate"] != -1)
].shape
# Out:
# (63978, 7)
